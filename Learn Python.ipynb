# %%
# LEARNING  THE BASIC FUNCTIONS AND TRICKS IN PYTHON
#Data types are Strings,integers,float,complex, and bytes

# %%
#1 strings

print("Enter data from keyboard using input function")
name=input("what is your name? ") #input function returns a string value recieved


print()
print()
# from the user
print("string conatination eg 'hi+name'")

print("hi " + name)
print()
print()

print("concatinate name +'likes'+color")
name=input("what is your second name?  ")
color1=input("what is your favourite color?  ")


print(name+"  likes  "+color1)
print()
print()
print("alternative1")
#subtract a string from an integer
print("subtract a string from an integer by converting a string to int")
Birth_year=input("birth year: ")
age=2022-int(Birth_year)#converting a string to an integer because python cannot
print(f"your current age is:  {age}")
print()
print("alternative2")
yob =int(input("Year of Birth"))
age2=2022-yob

print(f"There is your age wow!: {age2}")
print()
print()
      
weight_in_pounds=input(" Enter your weight in pounds? ")
weight_kg=int(weight_in_pounds)*0.45
print("your weight in kg is:"+ str(weight_kg))
print()
print()

print("defining multiple strings")
print()
# defining multiple srings use 3 quotes
message="""
This message is intended for Patrick
thank you for contacting us 
we will see you soon

Thank you
"""
print(message)
print()
print()

print("python indexing")
# Indexing in python starts at 0, in a sequence it does not print up to last no.
x="python"
print(x)
print(f'first letter:  {x[0]}')# printing the first leter of python
print(f'second letter: {x[1]}')# printing the second leter of python
print(f'last letter: {x[-1]}')# printing the last leter of python
print(f'second last letter: {x[-2]}')# printing the  second last leter of python
print(f'first three letters: {x[0:3]}')# printing the first to 3rd leter of python
print(f'all except the first letter: {x[1:]}')# printing all leters of python except the first by default
print(f'all letter except the last letter: {x[:5]}')# printing all leters of python except last since 0 is by default
print(f'all letters: {x[:6]}')# printing all leters of python since 0 is by default
print()
print(f'all letters again:  {x[0:]}')
print(f'all letters except first and last: {x[1:-1]}')# printing all leters of python except last since 0 and last
another="copy the variable to another with all letters:  " + x[:]# copies x to another with all leters
print(another)
print()
print()
      
print("use of formatted string")
# formatted strings
first_name="Patrick"
last_name="Kaveke"
out_put=f"{first_name}  {last_name}  is a pilot"
print(out_put)
print() 
print()
      
# operations on a string
message2="PYTHON IS A SIMPLE LANGUAGE"
print(message2)
print("the length of the string")
print()
print(len(message2))# print the number of characters in message2
print()
print("convert the string into lower case")
print(message2.lower())# converting our content into lower case using method '.lower'
# methods apply specifically to a data type not like functions which may be dynamic

print()
print("index of s using message2.find(s) method")
print(message2.find("S"))# get the index of "S" in the string
print()
print("replace the word simple with complicated")
print(message2.replace("SIMPLE","COMPLICATED"))#replace simple with complicated

print()
print()
print("add a charactar in a string say n in python")

newchar='N'
position=6
string = message2[:position] + newchar + message2[position+1:]
print(string)
print()
print("check if the word python is in the variable mssage2")
print("PYTHON" in message2 )# check if word PYTHON in in message2
# Out:
# Enter data from keyboard using input function
# what is your name? patrick
#
#
# string conatination eg 'hi+name'
# hi patrick
#
#
# concatinate name +'likes'+color
# what is your second name?  Mbugua
# what is your favourite color?  blue
# Mbugua  likes  blue
#
#
# alternative1
# subtract a string from an integer by converting a string to int
# birth year: 1989
# your current age is:  33
#
# alternative2
# Year of Birth1989
# There is your age wow!: 33
#
#
#  Enter your weight in pounds? 130
# your weight in kg is:58.5
#
#
# defining multiple strings
#
#
# This message is intended for Patrick
# thank you for contacting us
# we will see you soon
#
# Thank you
#
#
#
# python indexing
# python
# first letter:  p
# second letter: y
# last letter: n
# second last letter: o
# first three letters: pyt
# all except the first letter: ython
# all letter except the last letter: pytho
# all letters: python
#
# all letters again:  python
# all letters except first and last: ytho
# ...

# %%
#2 Integers,float and complex


#a int(),float() Arithmetic operations 
#these are symbols used in mathematics,i.e, add, minus,multiply,divide etc
a,b = 50,30
print(a+b)#addation
print()
print(a-b)#subtaction
print()
print(a*b)#multipication
print()
#there are two types of division
print(f"{a/b} float result")# with forward slash retuns a floating number

print()

rounded=round(a/b,3)#rounded to 3 dcp
print(f"{rounded} rounded to 3 dcp")
print()
print(f"{a//b} integer results")# returns an integer
print()
print(a%b)# modulus ,supposed to return the remainder
print()
print(a**b)#exponent or power


# math fuctions which can be imported from module math
print()
print()
print("using Math module")
n=10.723
print(n)
print(f"{round(n)}  rounded to the nearest whole number")# rounding to nearest whole number
print(f"{round(n,2)}  rounded to 2 dcp")

print()
n1=-10.723
print(n1)
print(f"{abs(n1)}  absolute value of {n1}")# absolute


print()

import math
print(n)
print(f"{math.ceil(n)}  ceil of {n}")# see the meaning of ceil and floor snd many more on python 3 documentation
print(f"{math.floor(n)}   floor of {n}")

 
print()
print()
#b complex number

print ("initializing complex number")

print()
print("1 using complex()")

compl=complex(4,5)

print(compl)
print(f"{type(compl)}  check the type of {compl}")
print(f" real part of the complex  {compl} is : {compl.real}")
print(f" imaginary part of the complex  {compl} is : {compl.imag}")
print()
print("2 initializing complex numbers the normal way")
compl2=4+5j

print(compl2)

# %%
#3 bytes


bytesobj = b'52s3a6s1s2xA$as2'
print(bytesobj)

print()
print("include double quote in the sequence")
bytesobj2 = b'52s3a6"s1s2xA$as2'
print(bytesobj)
print()

print("include a singe quote, for this you must use escape character '\' inside ")
bytesobj3 = b'52s3a6s1s\'2xA$as2'
print(bytesobj3)
print()
print()
print("iterate over a byte")
bytesobj4 = b'52s3a6'

for byte in bytesobj4:
    print(byte)
    
print()
print()
print("conver byte to string and vice varsa")

#bytes to string
bytesobj5 = b'52s3a6s1s2xA$as2'
strobj = bytesobj5.decode("utf-8") 
print(f"{strobj} byte to string")
print()
#string to bytes
strobj2 = 'hello'
tostr = bytes(strobj2, "utf-8")
print(f"{tostr}  string to bytes")

# %%
# 4 Python Data Structures

#Python Data Structures: Lists, Dictionaries, Sets, Tuples 
#Data structures in python can be categorised into Mutable and immutable
#Mutable|changeable data structures are, Lists,Dictionaries and sets while immutable is Tuple

# %%
# a) Lists

print('a) Lists \n')


list1=[] # empty list
print('empty list',list1,'\n')

list2=[20,23,56,12,'name','email',24]
print(list2,'\n')

for item in list2:
    print(item)
print()

print('# Create an empty list using the list() constructor \n')
# Create a three-element list from a tuple using the list() constructor

list4 = list((1, 2, 3))
print(list4)
print(f'first element {list4[0]} \n')# print first element

print('slicing a list')
list2=[20,23,56,12,'name','email',24]
print(list2,'\n')
print(f'from 3rd element to last: {list2[2:]} \n')

print(f"Second and third elements of list: {list2[1:3]} \n")# the last index value is not printed


list2=[20,23,56,12,'name','email',24]
print(list2)
print()
print('Append/add elements in  a list,use  .append()')
# Append a new element to the list l1
list2.append('location')

# Print the modified list
print("Appended location  to the list : \n")
print(list2)

# Remove element 5 from the list l1
print("removing the element in the list use .remove('location') \n")
list2.remove('location')


# Print the modified list
print("Removed element 'location'  from the list:")
print(list2,'\n')


# Change value at index 2 (third element) in list2
print('# Change value at index 3 (fouth element) in list2 \n')
list2[3] = 100
print(list2)
print()
print('A look at list methods \n')
print(' \n 1) .append() \n','2) .count() \n','3) .index \n','4) .reverse() \n'
     ,'5) .pop() \n','6) .sort() \n','7) .remove() \n','8) .clear() \n',
      '9) .insert() \n','10) .extend() \n','11) .copy() \n'
     )


fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']
print(fruits,'\n')
print('apple count ')
print(fruits.count('apple'))# count tangerine in the list
print('Index of banana')
print(fruits.index('banana'),'\n')# index of banana

print('Find next banana starting at position 4')
print(fruits.index('banana', 4),'\n')  # Find next banana starting at position 4
print ('indexes of banana starting from index = 4 to the last= 6 or whichever choice \n')
print(fruits.index('banana', 4, 7))

fruits2 = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']
print(fruits2,'\n')
print('Insert item in a list using .insert(),only in the beggining or last point \n')
fruits2.insert(0,'rangi1')# insert rangi in index 0
print(fruits2)
print()
fruits2.insert(len(fruits2),'rangi2')# insert rangi in last index
print(fruits2)
print()
print('reverse the order of the list by starting with the end item using , .reverse()')
fruits2.reverse()
print(fruits2)
print( 'Remove the item at the given position in the list, and return it.eg the fifth item \n')
print(fruits2.pop(4))
print('clear all elements \n')
print(fruits2.clear())
print()

print(' Using Lists as Stacks \n')
print('in stacks the principle is (“last-in, first-out”). \n')
stack = [3, 4, 5]
stack.append(6)# add 6
stack.append(7)# add 7
print(f'full list: {stack}')
print(f' the last item added is : {stack.pop()} \n')
print(stack)
print(f' the last item left is : {stack.pop()} \n')
print(stack)
print(f' the last item left is : {stack.pop()} \n')
print(stack)
print(f' the last item left is : {stack.pop()} \n')
print(stack)
print()

print('Using Lists as Queues \n')
print(' In a Queue the first element added is the first element retrieved (“first-in, first-out”); \n')

print('To implement a queue,  use collections.deque')
print('which was designed to have fast appends and pops from both ends. For example: \n')

from collections import deque
queue = deque(["Eric", "John", "Michael"])
queue.append("Terry")           # Terry arrives
queue.append("Graham")          # Graham arrives
print(queue,'\n')
print(f'first to arrive: {queue.popleft()} \n')                 # The first to arrive now leaves


print(queue,'\n')
print(f'next who had arrived: {queue.popleft()}') # The second to arrive now leaves
print(queue,'\n')

print(f'last arrival: {queue.pop()} \n')

print(f"remainder of arrivals: {queue} \n")


print('List Comprehensions \n')
print('This is a concise way of creating lists eg, assume we want to create a list of squares,\n')
print('1) create an empty list then append on  it the squared iterable x \n')
squares = []
for x in range(10):
    squares.append(x**2)
    print(x,'\n')

print(squares)
print()
print('2) use lambda fumction to implement the same in one line \n')
squares = list(map(lambda x: x**2, range(10)))
print(squares)
print()
print('3)this can easily done in one line as follows using list comprehension \n')
squares = [x**2 for x in range(10)]
print(squares)

print()
print('The del statement \n')

print('This is a way to remove an item from a list given its index instead of its value \n')

addition=[i+1 for i in range(3,15)]
print(addition)
print('delete the first value')

del addition[0]
print(addition,'\n')

print('delete from index 4:10')
del addition[4:10]
print(addition,'\n')

print('delete all')

del addition[:]
print(addition)

# %%
# b Dictionaries
#These are mutable data structures that contain a collection of keys and, associated with them, values.

print('b) Dictionaries \n')

# Create an empty dictionary using curly brackets
print('empty dictionary \n')
d1 = {}
print(d1)
# simple dictionary
print('a simple dictionary')

d2={'name':'John','age':27,'Hometown':'boston'}
print(d2)
print('the name is: ', d2['name'],'\n')
print ('method 1 all details \n')
for x in d2:
    print(x, ':', d2[x],'\n')
    
print ('method 2 all details \n') 

for key,value in d2.items():
    print(key,':',value,'\n')
# Create an empty dictionary using the dict() constructor
print('Create an empty dictionary using the dict() constructor \n')
d4 = dict()
print(d4)

# Create a two-element dictionary using the dict() constructor
print('Create a  dictionary using the dict() constructor with assigning variables \n')
d5=dict(name1='Nairobi',rank1=1,name2='Mombasa',rank2=2,name3='Eldoret',rank3=3)
print(d5,'\n')
x = dict(name = "John", age = 36, country = "Norway")
print(x,'\n')

# Create a two-element dictionary using the dict() constructor
print('create a two element dict using dict() and in  a list of lists \n')
d6 = dict([["name", 'John'], ["age", 21]])  # Note that we created the dictionary from a list of list

print(type(d6))
print(d6,'\n')


# Create a two-element dictionary using curly brackets
# Note that the  dictionary has a more complex structure as its values are dictionaries themselves!
print('Nested dictionaries')
dn1= {"John": {"Age": 27, "Hometown": "Boston"}, "Rebecca": {"Age": 31, "Hometown": "Chicago"}}
print(dn1)
print('John data is',dn1['John'],'\n')
print('every item in d3 using for loop \n')
for key ,details in dn1.items():
    print(key,'\n')
    for key in details:
        print(key,':',details[key])

people = {1: {'name': 'John', 'age': '27', 'sex': 'Male'},
          2: {'name': 'Marie', 'age': '22', 'sex': 'Female'},
          3: {'name': 'Luna', 'age': '24', 'sex': 'Female', 'married': 'No'}}

print(people,'\n')
print('access individual items')
print(people[1]['name'])
print(people[1]['age'])
print(people[1]['sex'],'\n')

print('Add another dictionary to the nested dict \n')
people[4] = {'name': 'Peter', 'age': '29', 'sex': 'Male', 'married': 'Yes'}
print(people,'\n')
print(people[4],'\n')
print('Iterate on a nested dictionary')

for key ,details in people.items():
    print(key,'\n')
    for key in details:
        print(key,':',details[key])
    
print()
print('delete elements in a dictionary \n')

del people[3]['married']
del people[4]['married']

print(people[3])
print(people[4])
print()
print('delete a dictionary in a nested dictionary \n')

del people[3], people[4]
print(people)

# %%
# c Sets

print('sets \n')
# Create a set using curly brackets
print('# Create a set using curly brackets \n')

s1 ={1,3,4,7,9}

print(s1)
# Create a set using the set() constructor
s2 = set([8, 10, 19, 4])

print(s2)

print('Sets union()/merging sets \n')

serials={'maize','beans','millet','sorghum'}
fruits={'apple','banana','mangoes','paw paw'}

print('method1 using union() \n')
ser_fruits=serials.union(fruits)

print(ser_fruits,'\n')

print('method2 # Create a union of two sets using the | operator \n')

print(fruits|serials)
print()
print('create sets with similar elements, note only one will appear in a union \n')
fruits1={'apple','banana','mangoes','paw paw'}
fruits2={'apple','orange','mangoes','lemon'}

print('\n',fruits1,'\n',fruits2,'\n')
unionf1andf2=fruits1|fruits2
print(unionf1andf2)

print('Find which elements appear on both sets \n')
print('method1 using the intersection() constructor \n')
interf1f2=fruits1.intersection(fruits2)

print(interf1f2,'\n')

print('method2 using the ampersand (&) operator \n')
print(fruits1&fruits2)

print()
print('return the difference in two sets (which elements are not in the other set) \n')
print('method 1 use difference() constructor \n')

print(fruits1.difference(fruits2))
print()
print('method2 use (-) operator \n')
print(fruits2-fruits1)

# %%
#d Tuples
print('Tuples are immutable. We would use tuples if we needed a data structure that, once created,')
print(' cannot be modified anymore \n')


print('method1 just number of values seperated by ,')

t1 = 12345, 54321, 'hello!'

print(t1)
print('method2 create a tuple using ()')
t2 =(1,2,33,44,5,6)
print(t2,'\n')

print('method3 using tuple() constructor \n')
t3 = tuple([1,2,3,4,5])
print(t3,'\n')

print('Tuples can also be used as dictionary keys \n')
# Use tuples containing mutable objects as dictionary keys
working_hours = {("Rebecca", 1): 38, ("Thomas", 2): 40}

print(working_hours)

# %%
# 5 if statements


# these evaluates the programe condation and if true then the condition is excecuted

print("if statement")

print()
print("1 where boolean expression or condition is True")
a,b =4,7
if a<b:
    print(f"{a} is less than  {b}")

print()
print()

print("if with multiple conditions")
print()

n1,n2,n3=9,4,2
if n1>n2 and n1>n3:
    print(f"{n1} is greater than  {n2}  and {n3}")

 
print()
print()
print("if statement evaluating to a number")

k=7
if k:
    print(f"{k}  is not zero")
    
    
print()
print()


print("nested if statement")
print()
print
n= 3
if n !=0:
    print(n, "is not equal zero")
    if n>0:
        print(n, "is positive")
        
    if n<0:
        print(f"{n} is negative")
        
        
print()
print()

print("if ,else statement")
print()
print("if statement evaluates to True hence if part executed")
m=8
l=11
print(m,l)
if m<l:
    print(m, "is less than" , l)
else:
    print(l, "is greater than", m)
    
print()
print()

print("if statement evaluates to False hence else part executed")
print(l,m)
m=8
l=11

if m>l:
    print(m, "is less than" , l)
else:
    print(l, "is greater than", m)
    
print()
print()
x = 2
y = 4
z = 5
print(x,y,z) 
if x<y:
    print(x, 'is less than', y)
    if z<y:
        print(z, 'is less than', y)
    else:
        print(z, 'is not less than', y)
else:
    print(x, 'is not less than', y)
    
print()
print()

is_hot=True
if is_hot:
    print("it's a hot day")
    print("drink plenty of water")
else:
    print("it's a cold day")
    print("wear warm clothes")
print("enjoy your day")
# when the condition is False it prints the else part
print()
print()

is_hot=False
if is_hot:
    print("it's a hot day")
    print("drink plenty of water")
else:
    print("it's a cold day")
    print("wear warm clothes")
print("enjoy your day")
# what if it's not hot neither cold? it's a lovely day right? see this below
print()
print()


# if,elif and else
is_hot=False
is_cold=False
if is_hot:
    print("it's a hot day")
    print("drink plenty of water")
elif is_cold:
    print("it's a cold day")
    print("wear a warm cloth")
else:
    print("it's a lovely day")
print("enjoy your day")


print()
print()
print("if, elif and else statements ")

s=16
u=59
v=16

print(s,u,v)
if s>u:
    print(s,"is grater than",u)
elif s==v:
    print('both',s ,'and',v ,'are equal')
    
elif s<v:
    print(s,'is less than', u)
elif u==v:
    print('both',u,'and',v,'are equal')
    
else:
    print('only',s,'and',v,'are equal')

    
print()
print()

p = 9

if p<0:
    print(a, 'is negative')
elif p==0:
    print('its a 0')
elif p>0 and p<10:
    print(p, 'is in (0,10)')
else:
    print(p, 'equals or greater than 10')

# %%
# 6 python loops


#a for loop

print("for loop with a range say 1-9")
print()

for i in range(1,9):
    print(i)
    
print()
print()

print("for loop with list")
print()

for j in ['c','c++','python','rubis']:
    print(j)
    
print()
print()
print("for loop with tuple")
print()
print('ascending order using sorted()')

tup=(21,35,78,90,11) 
tupsorted=sorted(tup)
for k in tupsorted:
    print(k)

print()
print()

print('descending order using sorted()')

tup2=(21,35,78,90,11) 
tupsorted2=sorted(tup2,reverse=True)
for k in tupsorted2:
    print(k)

print()
print()
print("for loop with dictionary")
print()

dict1={'name':'python', 'category':'programming', 'topic':'examples'}
 
for item in dict1:
    print(item,':',dict1[item])
    
print()
print()

print("for loop with set")

myset ={'python', 'programming', 'examples'}
for p in myset:
    print(p)
    
print()
print()
print("for loop with a string")
word1='pythonlanguage'
for letter in word1:
    print(letter)
    
    
print()
print()
print('python for loop - break')
for n in range(2, 10):
    if n==7 :
        break
    print(n)
    
    
print()
print()
print('python for loop - continue')
for n in range(2, 10):
    if n==7 :
        continue
    print(n)
    
    
print()
print()
print('for loop with else block')

for l in range(24, 30):
    print(l)
else:
    print('Out of for loop')
    
    
print()
print()
print('nested for loop')
for x1 in range(5):#value printed
    for y1 in range(6):#acts as the x1 values length 
        print(x1, end=' ')# use the range of y1 to printx1 to the end
    print()
    
print()
print()


# b while loop

print("print 1 to n with while loop")

t=10
i=1

while i<=t:
    print(i)
    i +=1
    
print()
print()
print("while loop with break ")
a = 10
i = 0
while i<a:
    print(i)
    i+=1
    if i>7:
        break
   

print()
print()
print("while loop with continue")
a = 10

i = 0
while i<a:
    print(i)
    i+=1
    if i>7:
        continue
        
print()
print()
print('looping a string')
print()

# looping a string
n=1
while n<=6:
    print("*" *n)
    n+=1
print("A triangle created")


print()
print()
print('create a guessing game')
print()
# problem
#create a guessing game
secret_number=9
guess_count=0
guess_limit=3
while guess_count < guess_limit:
    guess=int(input("Guess the secret number:  "))
    guess_count +=1
    if guess==secret_number: 
        print("Alaah you won! " + "congratulation")
        break
else:
    print("Sorry you failed! ")

# %%
# 7 python functions Basics

#a functions without a parameter

print('functions without a parameter')
print()
print('1)')
def my_string():
    greetings ='hello'
    name=input('What is your name?')
    message=print(greetings,name,'!')

my_string()


print()
print()
print("2)")
print('addation then sqrt() results')
def operations():
    
    a=2
    b=7
    add=a+b
    import math
    sq=math.sqrt(add)
    print(sq)
        
operations()

print()
print()
print('Functions with auguments')
print()
#def details(fname,lname):
    #print(fname,lname , 'cool names')
#details(input('your first name: '),input('your last name: '))

#print()
#print()

def Sum1(a,b,c):
    sum=a+b+c
    print(sum)
Sum1(6,4,9)

print()
print('*args and  **kwargs, the  * and ** are called unpacking operators')
print()
print('*args is an arbitrary argument that makes the function accept multiple no of positional parameters')
print('*args is a tuple')
print("*args individual values can be accessed using for loop or indexing")
print()
print('access the tuple in general')
print()
def family(*children):
    print('all my childen are: ',children)# indexes the third child name auguments
    
family('mulwa','john','kasee')
print()
print('the name of the third child through indexing')
print()

def family2(*children):
    print('name of the third child is: ',children[2])

family2('mulwa','john','kasee')
print()
print('access all individual values using for loop')
print()
def family3(*children):
    for childname in children:
        print(childname)

family3('mulwa','john','kasee')
print()
print()

print("keyword augument,initializes the augument up on function call")
print()
def myfamily(child1,child2,child3,child4):
    
    print('1) ',child3)
    print('2) ',child2)
    print('3) ',child4)
    print('4) ',child1)
    
myfamily(child4='jane',child1='john',child2='pascal',child3='Njoroge')
print()
print()
print('**kwargs allows function call to pass various number of keyword/named arguments to the function')
print("datatype in **kwargs is a dictionary printing as ,key: value format")
print()
    
print('access the dictionary in a general')
print()
def myfamily(**kids):
    print('all my kids:',kids)
    
myfamily(child4='jane',child1='john',child2='pascal',child3='Njoroge')
print()
print()
print('accessing individual content by key in a specific order')
def myfamily(**kids):
    
    print('1) ',kids['child3'],'first born')
    print('2) ',kids['child2'],'second born')
    print('3) ',kids['child4'],'third born')
    print('4) ',kids['child1'],'last born')
    
myfamily(child4='jane',child1='john',child2='pascal',child3='Njoroge')
print()
print()
print("access using for loop")
print('1)')
def myfamily(**kids):
    for kw in kids:
        print(kw, '-', kids[kw])
    
myfamily(child4='jane',child1='john',child2='pascal',child3='Njoroge')
print()
print()
print('2)')
def myFunction2(**kwargs):
    for kw in kwargs:
        print(kw, '-', kwargs[kw])

if __name__ == "__main__":
    myFunction2(a = 24, b = 87, c = 3, d = 46)
    
print()
print()
print('3)')
print("*kwargs with other parameters ")
def myFunction3(x, y, **kwargs):
    print(x)
    print(y)
    for key, value in kwargs.items():
        print(key, '-', value)

if __name__ == "__main__":
    myFunction3("ABC", "MNO", a = 24, b = 87, c = 3, d = 46)


print()
print()
print('using both *args and **kwargs in a function')
print()
def myFunction(*args, **kwargs):
    print(args)
    print(kwargs)

if __name__ == "__main__":
    myFunction("hello", "mars", a = 24, b = 87, c = 3, d = 46)

    
print()
print()
print('default parameters,returned whenever the function is called without a parameter')
print()
def citizen(country='Kenyan'):
    print('I am a, ',country)
    
citizen('Ugandan')
citizen('Tanzanian')
citizen('Somali')
citizen()

print()
print()
print('passing a list as an augument')
print()
def dishes(food):
    
    for x in food:
        print(x)

fruits = ["apple", "banana", "cherry"]

dishes(fruits)

print()
print()
print('functions  with return values')
print()
print('1)')

def subtract(m):
   
    return 17-m

print(subtract(5))
print(subtract(18))
print(subtract(1))
print(subtract(7))

print()
print()

print('Return multiple values')
print()
print("2)")

import math
def general(j,k,g):
    add=j+k+g
    root=math.sqrt(add)
    return add,root
print(general(10,12,27))

print()
print()
print('1)')
print('function recursion,which means a function calls itself')
print()

def try_recursion(k):
    
    if(k > 0):
        result = k + try_recursion(k - 1)
        print(result)
    else:
        result = 0
    return result

print("\n\nRecursion Example Results")
try_recursion(6)


print()
print('2)')
print("factorial of a number")
print()

def factorial(n):
    result = 1
    if n > 0 and n>1:
        #if n > 1:
        return n * factorial(n - 1)
    return result

n = int(input('n : '))
print('n! =', factorial(n))

# %%
#8 Advanced topic on Functions

#Return function from a function
print('Return function from a function')
print()
print('executed by simply defining a func in another func and calling the mother func')

print()
def function1():
    return function2

def function2():
    print('Function 2')

x = function1()
x()

print()
print()
print('return a function by referencing it in another function')
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def arithmeticoperation(operation):
    if operation==1:
        return add
    elif operation==2:
        return subtract
    elif operation==3:
        return multiply

while True:
    print('Arithmetic Operations')
    print('1. Addition')
    print('2. Subtraction')
    print('3. Multiplication')
    print('0. Exit')
    operation = int(input('Enter the arithmetic operation : '))
    if(operation==0):
        break
    func = arithmeticoperation(operation)
    a = int(input('Enter a : '))
    b = int(input('Enter b : '))
    result = func(a, b)
    print('The result is :', result)
    print()
    break
    
    print()
    print()
    print("inner functions")
    print("these are functions defined in a function")
    print()
def function():
    print('mother function.')

    def innerFunc1():
        print('Inner function 1.')

    def innerFunc2():
        print('Inner function 2.')

    innerFunc1()
    innerFunc2()
function()

print()
print()
print('lambda function')
print('syntax, lambda arguments : expression')
print()
print('1)')
print('1 argument')
square = lambda a: a*a
#call lambda function
result = square(7)
print(result)
print()
print()
print('2)')
print("multiple argument")
mul = lambda a,b: a*b
#call lambda function
result = mul(5,3)
print(result)
print()
print()
print("3)")
print("lambda function without argument")
#lambda function

six = lambda : 6
#call lambda function
result = six()
print(result)
print()
print()
print("4)")
print ("recursive lambada function")

#recursive lambda function
factorial = lambda a: a*factorial(a-1) if (a>1) else 1
#call lambda function
result = factorial(5)
print(result)

print()
print()
print("5)")
print("returning lambda function in another function, mostly used for this")
def myfunc(n):
    return lambda a : a * n
mydoubler = myfunc(2)# n=2
mytripler = myfunc(3)# n=3
print(mydoubler(11))# a=11
print(mytripler(11))#a=11

print()
print()
print("list of functions")
print()
print('Functions are just like any other objects in python therefore can be passed ')
print("arguments or items in a set,list and as a value in  key:value set up like dictionary")
print()   
print("list")     
print()
    
def function1():
    print('in a list as first item')

def function2():
    print('in a list as second item')

mylist = [function1, function2]

print(mylist)

# %%
#9 python classes and objects

print("simplest class definition")
print()
class Numbers:
    x=1
    y=2
    z=3
# create an object num
num=Numbers()
print('x =',num.x)
print('y =',num.y)
print('z =',num.z)
print()
print()
print("defining a class with parameters, the __init__(self,) function")
print()

class PersonalDetails:
    def __init__ (self,fname,lname,age,email,country,location):
        self.fname=fname
        self.lname=lname
        self.age=age
        self.email=email
        self.country=country
        self.location=location
#create an object
personal=PersonalDetails('John','Nyongesa',45,'nyong@gmail.com','Srilanka','Nehlu')
print('First name :',personal.fname,'\n' )
print('Last name :',personal.lname,'\n' )
print('Age :',personal.age,'\n' )
print('Email :',personal.email,'\n' )
print('Country :',personal.country,'\n' )
print('Location :',personal.location,)

print()
print()
print("the string representation of a class object")
print()

class PersonalDetails:
    def __init__ (self,fname,lname,age,email,country,location):
        self.fname=fname
        self.lname=lname
        self.age=age
        self.email=email
        self.country=country
        self.location=location
        
#create an object
personal=PersonalDetails('John','Nyongesa',45,'nyong@gmail.com','Srilanka','Nehlu')
print('First name :',personal.fname,'\n' )
print('Last name :',personal.lname,'\n' )
print('Age :',personal.age,'\n' )
print('Email :',personal.email,'\n' )
print('Country :',personal.country,'\n' )
print('Location :',personal.location,)

print()
print()
print('Python inheritance')
print()

class Person:
    
    def __init__(self,fname,lname):
        
        self.Firstname=fname
        self.Lastname=lname
    def printname(self):
        
        print(self.Firstname,self.Lastname)
        
class Student(Person):
    
    def __init__(self, fname, lname,year):# overrides the parent __init__()
        #Person.__init__(self, fname, lname)#calls the parent __init_()
        super().__init__(fname, lname)# super()makes child class inherit all from parent
        self.gradyear=year
    def welcome(self):
        print('Welcome!, ',self.Firstname,self.Lastname ,'to the class of',self.gradyear)

pers=Person('patrick','mbugua')
st=Student('alison','mweru',2020)
pers.printname()
st.welcome()

# %%
#10 Python Iterators and Iterable

print('An iterator is an object that contains a countable number of values and can be Iterated on.')
print()
print('python iterable are:')
print('\n Lists \n','Tuples \n','Dictioneries \n','Sets \n','String ')
print('\n These objects have methods __iter__() and __next__() used to get and traverse an iterable')

print()
print('1. eg a tuple \n')

mytuple =('Beans','Maize','Wheat','Millet')
print('Print each value in mytuple')
intuple=iter(mytuple)

print(next(intuple))
print(next(intuple))
print(next(intuple))
print(next(intuple))
print()
print('2 .String \n')

mystr = "banana"
print(mystr,'\n')
instr = iter(mystr)

print(next(instr))
print(next(instr))
print(next(instr))
print(next(instr))
print(next(instr))
print(next(instr),'\n')
print('You can print every item in an iterable by looping through \n')

mytuple =('Beans','Maize','Wheat','Millet')
for item in mytuple:
    print(item)

print('Creating an iterator object,__iter__(),and __next() usage \n')
print('Create an iterator that returns numbers, starting with 1,')
print('and each sequence will increase by one (returning 1,2,3,4,5 etc.): ','\n')

class MyNumbers:
    
      def __iter__(self):
        self.number = 1
        return self

      def __next__(self):
        x = self.number
        self.number += 1
        return x
#create object
myclass = MyNumbers()
#create iterable
myiter = iter(myclass)

print(next(myiter))
print(next(myiter))
print(next(myiter))
print(next(myiter))
print(next(myiter))

print()
print('StopIteration statement when using a loop \n')
class MyNumbers:
    
    def __iter__(self):
        
        self.number = 1
        return self
    
    def __next__(self):
        if self.number <= 10 :
            
            x = self.number
            self.number += 1
            return x
        else:
            raise StopIteration
#create object
myclass = MyNumbers()
#create iterable
myiter = iter(myclass)

for x in myiter:
    print(x)

# %%
#11 Python scope
print('A variable is only available from inside the region it is created. This is called scope. \n')
print('1) Local scope \n')
print('A variable created inside a function belongs to the local scope of that function')
print('and can only be used inside that function.\n') 

print(' a function with loacal variables')
def add():
    a=12
    c=25
    adding=a+c
    print(adding)
add()

print('\n local variable is accessed by another function inside the main function \n')
def add():
    a=12
    c=25
    def operation():
        adding=a+c
        print(adding)
    operation()
    
add()

print(' \n 2)  Global Scope \n')
print('A variable created outside of a function is global and can be used by anyone:\n')

a=29
b=10
def add():
    adding=a+b
    print(adding)
    
add()
print(f' \n we added {a}\n  and {b} \n to get {a+b} \n')
print('3) Naming Variables \n')
print('if you use the same variable globally and lically pyhton treats them as different variables')
print('the function will print the local x, and then the code will print the global x:')
x = 300

def myfunc():
    x = 200
    print('locally declared',x)

myfunc()

print('globally declared',x)
print()
print('4) The Global Keyword \n')
print('The global keyword makes the variable global and accessible anywhere. \n')
def number():
    global z
    z=100
    print('local print of',z)
    
number()
print('global print of',z)
print()
print('5) Global is also used to change the value of a variable inside a function \n')

v=500
def changenumber():
    v=280
    print('local print of',v)
    
changenumber()
print('global print of v is',v)

# %%
#12 Python Dates
print('A date in Python is not a data type of its own,')
print('but we can import a module named datetime to work with dates as date objects. \n')
print('Import the datetime module and display the current date:\n')

import datetime
print('The date contains year, month, day, hour, minute, second, and microsecond. ')
datetimevar= datetime.datetime.now()
print(datetimevar)
print()
print('The datetime module has many methods to return information about the date object.\n')
print('1) Return the year and name of weekday:')

import datetime
print('The date contains year, month, day, hour, minute, second, and microsecond. ')
datetimevar= datetime.datetime.now()
print(datetimevar.year)#year
print(datetimevar.strftime("%A"))# weekday
print()
print('2) Creating Date Objects \n')
print('The datetime() class requires three parameters to create a date: year, month, day.\n')
print('The datetime() class also takes parameters for time and timezone (hour, minute, second, microsecond, tzone)')
print(', but they are optional, and has a default value of 0, (None for timezone).\n')

import datetime
datetimevar= datetime.datetime(2022, 11, 17)
print(datetimevar)
print()
print('3) The strftime() Method \n')
print('The datetime object has a method for formatting date objects into readable strings.')
print('which is called strftime(),')
print('and takes one parameter, format, to specify the format of the returned string:\n')
print('Display the name of the month:')

import datetime
datetimevar= datetime.datetime(2022, 11, 17)
print(datetimevar)
print(datetimevar.strftime("%B"))
print()
print('A reference of all the legal format codes are as follows: \n')
print("%a",'	Weekday, short version eg 	 Wed')
print("%A",'Weekday, full version	Wednesday')
print("%d",'Day of month 01-31	31') 
print("%b",'	Month name, short version	Dec')
print("%B",'Month name, full version	December')
print("%m",'Month as a number 01-12	12')
print("%y",'Year, short version, without century	18')
print("%Y",'	Year, full version	2018''')
print("%z",'	UTC offset	+0100')
print("%Z",'Timezone	CST')
print("%c",'	Local version of date and time	Mon Dec 31 17:41:00 2018')
print("%x",'	Local version of date	12/31/18') 
print("%X",'	Local version of time	17:41:00')
print("%G",'	ISO 8601 year	2018	')
print("%u",'	ISO 8601 weekday (1-7)	1	')
print("%V",'	ISO 8601 weeknumber (01-53)	01')
# Out:
# A date in Python is not a data type of its own,
# but we can import a module named datetime to work with dates as date objects.
#
# Import the datetime module and display the current date:
#
# The date contains year, month, day, hour, minute, second, and microsecond.
# 2022-11-08 17:58:48.091375
#
# The datetime module has many methods to return information about the date object.
#
# 1) Return the year and name of weekday:
# The date contains year, month, day, hour, minute, second, and microsecond.
# 2022
# Tuesday
#
# 2) Creating Date Objects
#
# The datetime() class requires three parameters to create a date: year, month, day.
#
# The datetime() class also takes parameters for time and timezone (hour, minute, second, microsecond, tzone)
# , but they are optional, and has a default value of 0, (None for timezone).
#
# 2022-11-17 00:00:00
#
# 3) The strftime() Method
#
# The datetime object has a method for formatting date objects into readable strings.
# which is called strftime(),
# ...
